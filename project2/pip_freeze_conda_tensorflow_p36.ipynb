# %%
# !pip freeze
# Out:
# absl-py==0.4.0
# appdirs==1.4.3
# asn1crypto==0.24.0
# astor==0.7.1
# attrs==18.1.0
# Automat==0.3.0
# autovizwidget==0.12.5
# backcall==0.1.0
# bleach==2.1.4
# bokeh==0.13.0
# boto3==1.7.82
# botocore==1.10.82
# certifi==2018.8.13
# cffi==1.11.5
# characteristic==14.3.0
# chardet==3.0.4
# constantly==15.1.0
# cryptography==2.3.1
# cryptography-vectors==2.3.1
# cycler==0.10.0
# Cython==0.28.4
# decorator==4.3.0
# docutils==0.14
# entrypoints==0.2.3
# environment-kernels==1.1.1
# gast==0.2.0
# grpcio==1.10.1
# h5py==2.8.0
# hdijupyterutils==0.12.5
# horovod==0.13.11
# html5lib==1.0.1
# hyperlink==17.3.1
# idna==2.7
# incremental==17.5.0
# ipykernel==4.8.2
# ipyparallel==6.2.2
# ipython==6.5.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.0
# jedi==0.12.1
# Jinja2==2.10
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-client==5.2.3
# jupyter-core==4.4.0
# Keras==2.2.2
# Keras-Applications==1.0.4
# Keras-Preprocessing==1.0.2
# kiwisolver==1.0.1
# Markdown==2.6.11
# MarkupSafe==1.0
# ...

# %% [markdown]
# All notebooks were run on the kernel Python[conda env:tensorflow_p36]
